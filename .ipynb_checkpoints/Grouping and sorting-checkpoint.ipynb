# %% [markdown]
# # Grouping and sorting

# %%
import pandas as pd
import numpy as np
pd.set_option('max_rows', 5)

# %%
reviews = pd.read_csv("oscar_age_female.csv")
pd.set_option('max_rows', 5)
reviews.head()
# Out:
#    Index  Year  Age               Name                            Movie  \
# 0      1  1928   22     "Janet Gaynor"                  "Seventh Heaven
# 1      2  1929   37    "Mary Pickford"                       "Coquette"
# 2      3  1930   28    "Norma Shearer"                 "The Divorcee"\t
# 3      4  1931   63   "Marie Dressler"                   "Min and Bill"
# 4      5  1932   32      "Helen Hayes"   "The Sin of Madelon Claudet"\t
#
#                                          Unnamed: 5
# 0   Street Angel and Sunrise: A Song of Two Humans"
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
reviews.groupby('Age').count()
# Out:
#      Index  Year  Name  Movie  Unnamed: 5
# Age
# 21       1     1     1      1           0
# 22       2     2     2      2           1
# ..     ...   ...   ...    ...         ...
# 74       1     1     1      1           0
# 80       1     1     1      1           0
#
# [32 rows x 5 columns]

# %%
countries_reviewed = reviews.groupby('Age').Movie.agg([len])
countries_reviewed.head()
# Out:
#      len
# Age
# 21     1
# 22     2
# 24     2
# 25     4
# 26     6

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Index  Year  Age               Name             Movie  \
# firstEntry       1  1928   22     "Janet Gaynor"   "Seventh Heaven
# secondEntry      2  1929   37    "Mary Pickford"        "Coquette"
# ...            ...   ...  ...                ...               ...
# 87              88  2015   54   "Julianne Moore"     "Still Alice"
# 88              89  2016   26      "Brie Larson"            "Room"
#
#                                                    Unnamed: 5
# firstEntry    Street Angel and Sunrise: A Song of Two Humans"
# secondEntry                                               NaN
# ...                                                       ...
# 87                                                        NaN
# 88                                                        NaN
#
# [89 rows x 6 columns]

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields  Index  Year  Age               Name             Movie  \
# wines
# 0           1  1928   22     "Janet Gaynor"   "Seventh Heaven
# 1           2  1929   37    "Mary Pickford"        "Coquette"
# ...       ...   ...  ...                ...               ...
# 87         88  2015   54   "Julianne Moore"     "Still Alice"
# 88         89  2016   26      "Brie Larson"            "Room"
#
# fields                                        Unnamed: 5
# wines
# 0        Street Angel and Sunrise: A Song of Two Humans"
# 1                                                    NaN
# ...                                                  ...
# 87                                                   NaN
# 88                                                   NaN
#
# [89 rows x 6 columns]
